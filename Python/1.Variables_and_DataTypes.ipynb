# %% [markdown]
# Variables
#
# A variable in Python is essentially a symbolic name assigned to a memory location where data is stored.(donot use keywords as variable names)
#
# a = 10 -> a = Variable name , = = assignment operator, 10m = value
#
# Indentation: 4 whitespace
#
# Typed Language:

# %% [markdown]
# Python Keywords
#
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
import keyword
print(keyword.kwlist)

# %% [markdown]
# Data Types
#
# data types are used to define the kind of data a variable can store.
#
# Numeric Data Types -> integer(+,-), float(1.23), complex(2+3j)
#
# Sequence Data Types -> String("Satya"), list([1,2,3,4,5]), tuple(1,2,3,4,5)
#
# Set Data Types -> set ({1,2,3,4,5}), frozenset()
#
# Mapping Data Type -> Dictionary({"name":"Satya","age":"25","gender":"Male"})
#
# Boolean Data Type -> True(1), False(0)
#
# Binary Data Types -> bytes, bytearray, memoryview
#
# None Data Type -> None

# %%
name = "Satya"
age = 25
height = 5.6
id = 2+3j
men = True
a=[1,2,3,4,5]
b=(1,2,3,4,5,6)
c={1,2,3,4,5,6}
d={"x":1,"y":2,"z":3}
print(type(name), type(age), type(height), type(id), type(men), type(a), type(b), type(c), type(d))
# Out:
# <class 'str'> <class 'int'> <class 'float'> <class 'complex'> <class 'bool'> <class 'list'> <class 'tuple'> <class 'set'> <class 'dict'>
