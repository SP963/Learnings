# %%
temp=int(input())
if temp < 30:
    print("very cold")
elif(temp > 30 and temp < 40):
    print('cool')
else:
    print("hot")

# %%
for i in range(10,101,10):
    print(i*i)
# Out:
# 100
# 400
# 900
# 1600
# 2500
# 3600
# 4900
# 6400
# 8100
# 10000

# %%
a='chandu'
for i in a:
    print(i)
# Out:
# c
# h
# a
# n
# d
# u

# %%
a=None
if (a):
    print("true")
else:
    print("false")
# Out:
# false

# %%
a='chandu'
b='mani'
print(a + ' is good')
print("{} is good {}".format(a,b))
# Out:
# chandu is good
# chandu is good mani

# %%
n={1:1,2:4,3:9}
for k,v in n.items():
    print("{} sqaure is {} at {}".format(k,v, v1))
# Out:
# 1 sqaure is 1
# 2 sqaure is 4
# 3 sqaure is 9

# %%
a='GREAT minds think alike'
v=['a','e','i','o','u']
for i in a:
    if i.lower() not in v:
        print(i +" is consonant")
# Out:
# G is consonant
# R is consonant
# T is consonant
#   is consonant
# m is consonant
# n is consonant
# d is consonant
# s is consonant
#   is consonant
# t is consonant
# h is consonant
# n is consonant
# k is consonant
#   is consonant
# l is consonant
# k is consonant

# %%
for i in range(10):
    print("Time: " + str(i))
    d1=int(input("dividend:"))
    d2=int(input("divisor:"))
    if(d2==0):
        print("don't provide zero")
        continue
    print(d1/d2)
print("completed")
# Out:
# Time: 0
# don't provide zero
# Time: 1
# 5.666666666666667
# Time: 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 4
#       2 print("Time: " + str(i))
#       3 d1=int(input("dividend:"))
# ----> 4 d2=int(input("divisor:"))
#       5 if(d2==0):
#       6     print("don't provide zero")
#
# ValueError: invalid literal for int() with base 10: '`'
